# %%
# imports
import numpy as np
from scipy.integrate import ode

# %%
def newton(t, Y, q, m, B):
    """Computes the derivative of the state vector y according to the equation of motion:
    Y is the state vector (x, y, z, u, v, w) === (position, velocity).
    returns dY/dt.
    """
    x, y, z = Y[0], Y[1], Y[2]
    u, v, w = Y[3], Y[4], Y[5]
    
    alpha = q / m * B
    return np.array([u, v, w, 0, alpha * w, -alpha * v])

# %%
r = ode(newton).set_integrator('dopri5')

# %%
t0 = 0
x0 = np.array([0, 0, 0])
v0 = np.array([1, 1, 0])
initial_conditions = np.concatenate((x0, v0))

# %%
r.set_initial_value(initial_conditions, t0).set_f_params(1.0, 1.0, 1.0)

positions = []
dt = 0.05
t1 = 20*dt #50
while r.successful() and r.t < t1:
    r.integrate(r.t+dt)
    positions.append(r.y[:3]) # keeping only position, not velocity
    print(r.y[:3])

positions = np.array(positions)
# Out:
# [ 0.05        0.04997917 -0.00124974]
# [ 0.1         0.09983342 -0.00499583]
# [ 0.15        0.14943813 -0.01122892]
# [ 0.2         0.19866933 -0.01993342]
# [ 0.25        0.24740396 -0.03108758]
# [ 0.3         0.29552021 -0.04466351]
# [ 0.35        0.34289781 -0.06062729]
# [ 0.4         0.38941834 -0.07893901]
# [ 0.45        0.43496553 -0.0995529 ]
# [ 0.5         0.47942554 -0.12241744]
# [ 0.55        0.52268723 -0.14747548]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(positions[:, 1], positions[:, 2])
